# %%
import pandas as pd

# Load your Excel dataset
df = pd.read_excel(r"C:\Users\noahi\Downloads\Nashville Housing Data.xlsx")

# Basic info
print("ROWS:", df.shape[0])
print("COLUMNS:", df.shape[1])
print("\nCOLUMN NAMES:")
print(df.columns.tolist())

print("\nDATA TYPES:")
print(df.dtypes)

print("\nMISSING VALUES:")
print(df.isnull().sum())

print("\nSAMPLE ROWS:")
print(df.head())

print("\nSUMMARY STATISTICS:")
print(df.describe(include='all'))
# Out:
# ROWS: 56477
# COLUMNS: 19
#
# COLUMN NAMES:
# ['UniqueID ', 'ParcelID', 'LandUse', 'PropertyAddress', 'SaleDate', 'SalePrice', 'LegalReference', 'SoldAsVacant', 'OwnerName', 'OwnerAddress', 'Acreage', 'TaxDistrict', 'LandValue', 'BuildingValue', 'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath']
#
# DATA TYPES:
# UniqueID                    int64
# ParcelID                   object
# LandUse                    object
# PropertyAddress            object
# SaleDate           datetime64[ns]
# SalePrice                   int64
# LegalReference             object
# SoldAsVacant               object
# OwnerName                  object
# OwnerAddress               object
# Acreage                   float64
# TaxDistrict                object
# LandValue                 float64
# BuildingValue             float64
# TotalValue                float64
# YearBuilt                 float64
# Bedrooms                  float64
# FullBath                  float64
# HalfBath                  float64
# dtype: object
#
# MISSING VALUES:
# UniqueID               0
# ParcelID               0
# LandUse                0
# PropertyAddress       29
# SaleDate               0
# SalePrice              0
# LegalReference         0
# SoldAsVacant           0
# OwnerName          31216
# OwnerAddress       30462
# Acreage            30462
# TaxDistrict        30462
# LandValue          30462
# BuildingValue      30462
# TotalValue         30462
# YearBuilt          32314
# Bedrooms           32320
# FullBath           32202
# HalfBath           32333
# dtype: int64
#
# SAMPLE ROWS:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress   SaleDate  SalePrice    LegalReference  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  20130412-0036474
# 1  1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  20140619-0053768
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  20160927-0101718
# 3  1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  20160129-0008913
# 4  1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  \
# 0           No           FRAZIER, CYRENTHA LYNETTE
# 1           No             BONER, CHARLES & LESLIE
# 2           No           WILSON, JAMES E. & JOANNE
# 3           No            BAKER, JAY K. & SUSAN E.
# 4           No  POST, CHRISTOPHER M. & SAMANTHA C.
#
#                              OwnerAddress  Acreage                TaxDistrict  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE, TN      2.3  GENERAL SERVICES DISTRICT
# 1  1832  FOX CHASE DR, GOODLETTSVILLE, TN      3.5  GENERAL SERVICES DISTRICT
# 2  1864  FOX CHASE DR, GOODLETTSVILLE, TN      2.9  GENERAL SERVICES DISTRICT
# 3  1853  FOX CHASE DR, GOODLETTSVILLE, TN      2.6  GENERAL SERVICES DISTRICT
# 4  1829  FOX CHASE DR, GOODLETTSVILLE, TN      2.0  GENERAL SERVICES DISTRICT
#
#    LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# 0    50000.0       168200.0    235700.0     1986.0       3.0       3.0
# 1    50000.0       264100.0    319000.0     1998.0       3.0       3.0
# 2    50000.0       216200.0    298000.0     1987.0       4.0       3.0
# 3    50000.0       147300.0    197300.0     1985.0       3.0       3.0
# 4    50000.0       152300.0    202300.0     1984.0       4.0       3.0
#
#    HalfBath
# 0       0.0
# 1       2.0
# 2       0.0
# 3       0.0
# 4       0.0
#
# SUMMARY STATISTICS:
#            UniqueID          ParcelID        LandUse  \
# count   56477.000000            56477          56477
# unique           NaN            48559             39
# top              NaN  081 16 0 250.00  SINGLE FAMILY
# freq             NaN                4          34197
# mean    28334.001133              NaN            NaN
# min         0.000000              NaN            NaN
# 25%     14186.000000              NaN            NaN
# 50%     28313.000000              NaN            NaN
# 75%     42513.000000              NaN            NaN
# max     56635.000000              NaN            NaN
# std     16352.590651              NaN            NaN
#
#                    PropertyAddress                       SaleDate  \
# count                        56448                          56477
# unique                       45068                            NaN
# top     1212  LAUREL ST, NASHVILLE                            NaN
# freq                           296                            NaN
# mean                           NaN  2015-02-08 08:02:27.373267200
# min                            NaN            2013-01-02 00:00:00
# 25%                            NaN            2014-04-11 00:00:00
# 50%                            NaN            2015-03-24 00:00:00
# 75%                            NaN            2015-12-30 00:00:00
# max                            NaN            2019-12-13 00:00:00
# std                            NaN                            NaN
#
#            SalePrice    LegalReference SoldAsVacant            OwnerName  \
# count   5.647700e+04             56477        56477                25261
# unique           NaN             52761            4                19713
# top              NaN  20150511-0042855           No  JRG PROPERTIES, LLC
# freq             NaN               116        51403                   26
# mean    3.272264e+05               NaN          NaN                  NaN
# min     5.000000e+01               NaN          NaN                  NaN
# 25%     1.350000e+05               NaN          NaN                  NaN
# 50%     2.051000e+05               NaN          NaN                  NaN
# 75%     3.285000e+05               NaN          NaN                  NaN
# max     5.427806e+07               NaN          NaN                  NaN
# std     9.298326e+05               NaN          NaN                  NaN
#
#                          OwnerAddress       Acreage              TaxDistrict  \
# count                           26015  26015.000000                    26015
# unique                          22331           NaN                        7
# top     0  MCKINLEY ST, NASHVILLE, TN           NaN  URBAN SERVICES DISTRICT
# freq                                7           NaN                    20024
# mean                              NaN      0.498923                      NaN
# min                               NaN      0.010000                      NaN
# 25%                               NaN      0.180000                      NaN
# 50%                               NaN      0.270000                      NaN
# 75%                               NaN      0.450000                      NaN
# max                               NaN    160.060000                      NaN
# std                               NaN      1.570454                      NaN
#
#            LandValue  BuildingValue    TotalValue     YearBuilt      Bedrooms  \
# count   2.601500e+04   2.601500e+04  2.601500e+04  24163.000000  24157.000000
# unique           NaN            NaN           NaN           NaN           NaN
# top              NaN            NaN           NaN           NaN           NaN
# freq             NaN            NaN           NaN           NaN           NaN
# mean    6.906856e+04   1.607847e+05  2.323754e+05   1963.744899      3.089912
# min     1.000000e+02   0.000000e+00  1.000000e+02   1799.000000      0.000000
# 25%     2.100000e+04   7.590000e+04  1.028000e+05   1948.000000      3.000000
# 50%     2.880000e+04   1.114000e+05  1.485000e+05   1960.000000      3.000000
# 75%     6.000000e+04   1.807000e+05  2.683500e+05   1983.000000      3.000000
# max     2.772000e+06   1.297180e+07  1.394040e+07   2017.000000     11.000000
# std     1.060401e+05   2.067999e+05  2.810643e+05     26.542982      0.852869
#
#             FullBath      HalfBath
# count   24275.000000  24144.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        1.886014      0.283921
# min         0.000000      0.000000
# 25%         1.000000      0.000000
# 50%         2.000000      0.000000
# 75%         2.000000      1.000000
# max        10.000000      3.000000
# std         0.961515      0.487881

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\noahi\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import openpyxl

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\noahi\\AppData\\Local\\Programs\\Python\\Python313\\python.exe'

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\noahi\appdata\local\programs\python\python313\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\noahi\appdata\local\programs\python\python313\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\noahi\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
